# %% [markdown]
# <a href="https://colab.research.google.com/github/MalshanNimesh99/Face_Antispoofing_System/blob/master/antispoofing_system.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !cp -r "/content/gdrive/MyDrive/Antispoofing_Dataset/final_antispoofing.zip" "/content"

# %%
import zipfile
archive = zipfile.ZipFile('/content/final_antispoofing.zip')
archive.extractall('/content')

# %%
dataset_dir = '/content/final_antispoofing'
train_dataset_dir = '/content/final_antispoofing/train'
test_dataset_dir = '/content/final_antispoofing/test'

# %%
import os
os.mkdir('/content/antispoofing_dataset')
os.mkdir('/content/antispoofing_dataset/train')
os.mkdir('/content/antispoofing_dataset/test')
os.mkdir('/content/antispoofing_dataset/train/real')
os.mkdir('/content/antispoofing_dataset/train/spoof')
os.mkdir('/content/antispoofing_dataset/test/real')
os.mkdir('/content/antispoofing_dataset/test/spoof')

# %%
train_dir='/content/antispoofing_dataset/train'
test_dir = '/content/antispoofing_dataset/test'

# %%
import shutil
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
def train_test_splits(data_directory):
  for split_type in os.listdir(data_directory):
    path_to_split_type = os.path.join(data_directory,split_type)
    for category in os.listdir(path_to_split_type):
      path_to_category = os.path.join(path_to_split_type,category)
      for subject in os.listdir(path_to_category):
        path_to_subject = os.path.join(path_to_category,subject)
        for img in os.listdir(path_to_subject):
          if split_type == 'train':
            shutil.copy(os.path.join(path_to_subject,img),os.path.join(train_dir,category,img))
          else:
            shutil.copy(os.path.join(path_to_subject,img),os.path.join(test_dir,category,img))

# %%
train_test_splits(data_directory=dataset_dir)

# %%
categories = ['real','spoof']

# %%
print("---------------------Exploring Training Datasets--------------------")
for category in categories:
  path = os.path.join(train_dir,category)
  if category == 'real':
    r1 = len(os.listdir(path))
  else:
    s1 = len(os.listdir(path))
  print("There are {} images in {} directory".format(len(os.listdir(path)),category))
print("There are {} total images in training directory".format(r1+s1))

print("-----------------------Exploring Testing Datasets-------------------------")
for category in categories:
  path = os.path.join(test_dir,category)
  if category == 'real':
    r2 = len(os.listdir(path))
  else:
    s2 = len(os.listdir(path))
  print("There are {} images in {} directory".format(len(os.listdir(path)),category))
print("There are {} total images in testing directory".format(r2+s2))
# Out:
# ---------------------Exploring Training Datasets--------------------
# There are 2102 images in real directory
# There are 2118 images in spoof directory
# There are 4220 total images in training directory
# -----------------------Exploring Testing Datasets-------------------------
# There are 477 images in real directory
# There are 474 images in spoof directory
# There are 951 total images in testing directory

# %%
def get_images(data_dir,number_of_samples):
  image_path = []
  for category in categories:
    path = os.path.join(data_dir,category)
    i = 1
    for img in os.listdir(path):
      if i > number_of_samples:
        break
      else:
        image_path.append(os.path.join(path,img))
        i += 1
  return image_path

# %%
def visualize_dataset(image_path,rows,cols):
  fig = plt.figure(figsize=(20,20))
  for i in range(1,rows * cols + 1):
    fig.add_subplot(rows,cols,i)
    img_array = cv2.imread(image_path[i-1])
    fig.subplots_adjust(hspace=1)
    plt.imshow(cv2.cvtColor(img_array,cv2.COLOR_BGR2RGB))
    plt.xlabel(image_path[i-1].split('/')[-2])
  plt.show()

# %%
training_image_path = get_images(data_dir= train_dir,number_of_samples=25)
print(training_image_path)
print(len(training_image_path))
# Out:
# ['/content/antispoofing_dataset/train/real/Sudeep Subedi36hr_flipbrightness0.58.jpg', '/content/antispoofing_dataset/train/real/samir ale gurung19.jpg', '/content/antispoofing_dataset/train/real/Shikshya Gautam47brightness1.25.jpg', '/content/antispoofing_dataset/train/real/Shikshya Gautam35hr_flip.jpg', '/content/antispoofing_dataset/train/real/dfgyhjnmk17.jpg', '/content/antispoofing_dataset/train/real/Shikshya Gautam45hr_flipbrightness1.29.jpg', '/content/antispoofing_dataset/train/real/kjdfjsdkfj29.jpg', '/content/antispoofing_dataset/train/real/Shikshya Gautam47.jpg', '/content/antispoofing_dataset/train/real/kjdfjsdkfj20.jpg', '/content/antispoofing_dataset/train/real/None24.jpg', '/content/antispoofing_dataset/train/real/WIN_20201119_10_49_00_Pro.jpg', '/content/antispoofing_dataset/train/real/Shikshya Gautam47hr_flipbrightness1.31.jpg', '/content/antispoofing_dataset/train/real/Saurav Ale6.jpg', '/content/antispoofing_dataset/train/real/Shikshya Gautam19hr_flipbrightness1.34.jpg', '/content/antispoofing_dataset/train/real/ddfgfhg44.jpg', '/content/antispoofing_dataset/train/real/Samir Gurung27.jpg', '/content/antispoofing_dataset/train/real/Shikshya Gautam46hr_flipbrightness1.34.jpg', '/content/antispoofing_dataset/train/real/fjdkjk2.jpg', '/content/antispoofing_dataset/train/real/WIN_20201110_13_23_32_Pro (2).jpg', '/content/antispoofing_dataset/train/real/hehehe19.jpg', '/content/antispoofing_dataset/train/real/ddfgfhg50.jpg', '/content/antispoofing_dataset/train/real/hghgh25.jpg', '/content/antispoofing_dataset/train/real/Sunil Koirala45brightness0.77.jpg', '/content/antispoofing_dataset/train/real/Suraj Khanal38hr_flip.jpg', '/content/antispoofing_dataset/train/real/dfjksjf8.jpg', '/content/antispoofing_dataset/train/spoof/samip49.jpg', '/content/antispoofing_dataset/train/spoof/bishal78.jpg', '/content/antispoofing_dataset/train/spoof/rihan123.jpg', '/content/antispoofing_dataset/train/spoof/sulav27.jpg', '/content/antispoofing_dataset/train/spoof/salina62.jpg', '/content/antispoofing_dataset/train/spoof/sumit200.jpg', '/content/antispoofing_dataset/train/spoof/sandy155.jpg', '/content/antispoofing_dataset/train/spoof/samip263.jpg', '/content/antispoofing_dataset/train/spoof/salina93.jpg', '/content/antispoofing_dataset/train/spoof/abhi105.jpg', '/content/antispoofing_dataset/train/spoof/samip267.jpg', '/content/antispoofing_dataset/train/spoof/samir99.jpg', '/content/antispoofing_dataset/train/spoof/bishal21.jpg', '/content/antispoofing_dataset/train/spoof/samir28.jpg', '/content/antispoofing_dataset/train/spoof/sumit90.jpg', '/content/antispoofing_dataset/train/spoof/bishal183.jpg', '/content/antispoofing_dataset/train/spoof/shikshya93.jpg', '/content/antispoofing_dataset/train/spoof/samip331.jpg', '/content/antispoofing_dataset/train/spoof/sandy151.jpg', '/content/antispoofing_dataset/train/spoof/abhi342.jpg', '/content/antispoofing_dataset/train/spoof/samir103.jpg', '/content/antispoofing_dataset/train/spoof/samir13.jpg', '/content/antispoofing_dataset/train/spoof/sulav60.jpg', '/content/antispoofing_dataset/train/spoof/sulav98.jpg', '/content/antispoofing_dataset/train/spoof/samir164.jpg']
# 50

# %%
visualize_dataset(image_path=training_image_path,rows=5,cols=10)

# %%
testing_image_path = get_images(data_dir= test_dir,number_of_samples=25)
print(testing_image_path)
print(len(testing_image_path))
# Out:
# ['/content/antispoofing_dataset/test/real/ghfdtrdtfyh19.jpg', '/content/antispoofing_dataset/test/real/hghgh47.jpg', '/content/antispoofing_dataset/test/real/Samir Gurung38.jpg', '/content/antispoofing_dataset/test/real/WIN_20201110_13_20_55_Probrightness1.26.jpg', '/content/antispoofing_dataset/test/real/Sunil Koirala42hr_flip.jpg', '/content/antispoofing_dataset/test/real/WIN_20201110_10_08_14_Prohr_flip.jpg', '/content/antispoofing_dataset/test/real/Sudeep Subedi49hr_flipbrightness0.71.jpg', '/content/antispoofing_dataset/test/real/WIN_20201110_13_21_23_Prohr_flip.jpg', '/content/antispoofing_dataset/test/real/dfjksjf12.jpg', '/content/antispoofing_dataset/test/real/Sunil Koirala25brightness0.6.jpg', '/content/antispoofing_dataset/test/real/Suraj Khanal37.jpg', '/content/antispoofing_dataset/test/real/WIN_20201110_13_22_58_Prohr_flipbrightness0.77.jpg', '/content/antispoofing_dataset/test/real/Suraj Khanal9brightness1.33.jpg', '/content/antispoofing_dataset/test/real/WIN_20201110_10_11_29_Prohr_flipbrightness0.66.jpg', '/content/antispoofing_dataset/test/real/jkhjhj1.jpg', '/content/antispoofing_dataset/test/real/Prabhat Ale38.jpg', '/content/antispoofing_dataset/test/real/Prabhat Ale16.jpg', '/content/antispoofing_dataset/test/real/Shikshya Gautam39hr_flipbrightness1.19.jpg', '/content/antispoofing_dataset/test/real/Sunil Koirala3brightness0.69.jpg', '/content/antispoofing_dataset/test/real/rftfyhbjnk21.jpg', '/content/antispoofing_dataset/test/real/Rihan Ale1.jpg', '/content/antispoofing_dataset/test/real/WIN_20201110_10_12_25_Probrightness1.1.jpg', '/content/antispoofing_dataset/test/real/WIN_20201119_10_49_17_Pro (2).jpg', '/content/antispoofing_dataset/test/real/Shikshya Gautam46hr_flip.jpg', '/content/antispoofing_dataset/test/real/samir ale gurung43.jpg', '/content/antispoofing_dataset/test/spoof/bishal197.jpg', '/content/antispoofing_dataset/test/spoof/abhi43.jpg', '/content/antispoofing_dataset/test/spoof/samip319.jpg', '/content/antispoofing_dataset/test/spoof/sandy71.jpg', '/content/antispoofing_dataset/test/spoof/abhi65.jpg', '/content/antispoofing_dataset/test/spoof/sulav173.jpg', '/content/antispoofing_dataset/test/spoof/rihan66.jpg', '/content/antispoofing_dataset/test/spoof/abhi238.jpg', '/content/antispoofing_dataset/test/spoof/rihan162.jpg', '/content/antispoofing_dataset/test/spoof/rihan331.jpg', '/content/antispoofing_dataset/test/spoof/samip199.jpg', '/content/antispoofing_dataset/test/spoof/shikshya218.jpg', '/content/antispoofing_dataset/test/spoof/sumit42.jpg', '/content/antispoofing_dataset/test/spoof/sumit173.jpg', '/content/antispoofing_dataset/test/spoof/samir68.jpg', '/content/antispoofing_dataset/test/spoof/rihan194.jpg', '/content/antispoofing_dataset/test/spoof/samir26.jpg', '/content/antispoofing_dataset/test/spoof/saurav226.jpg', '/content/antispoofing_dataset/test/spoof/shikshya153.jpg', '/content/antispoofing_dataset/test/spoof/sulav76.jpg', '/content/antispoofing_dataset/test/spoof/saurav45.jpg', '/content/antispoofing_dataset/test/spoof/abhi110.jpg', '/content/antispoofing_dataset/test/spoof/saurav88.jpg', '/content/antispoofing_dataset/test/spoof/abhi118.jpg', '/content/antispoofing_dataset/test/spoof/sumit167.jpg']
# 50

# %%
visualize_dataset(image_path=testing_image_path,rows=5,cols=10)

# %%
from keras.layers import Dense,Dropout,Input,Flatten
from keras.models import Model
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
from keras.applications.mobilenet_v2 import MobileNetV2
from keras.models import model_from_json
import json

# %%
train_datagen = ImageDataGenerator(brightness_range=(0.8,1.2),rotation_range=30,width_shift_range=0.2,height_shift_range=0.2,fill_mode='nearest',shear_range=0.2,zoom_range=0.3,rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(train_dir,target_size=(160,160),color_mode='rgb',
                                                    class_mode='binary',batch_size=25,shuffle=True)
# Out:
# Found 4220 images belonging to 2 classes.

# %%
valid_generator = valid_datagen.flow_from_directory(test_dir,target_size=(160,160),color_mode='rgb',
                                                    class_mode='binary',batch_size=25)
# Out:
# Found 951 images belonging to 2 classes.

# %%
mobilenet = MobileNetV2(weights="imagenet",include_top=False,input_tensor=Input(shape=(160,160,3)))
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 0s 0us/step

# %%
mobilenet.trainable = False

# %%
output = Flatten()(mobilenet.output)
output = Dropout(0.3)(output)
output = Dense(units = 8,activation='relu')(output)
prediction = Dense(1,activation='sigmoid')(output)

# %%
model = Model(inputs = mobilenet.input,outputs = prediction)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 160, 160, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 80, 80, 32)   864         ['input_1[0][0]']
#
#  bn_Conv1 (BatchNormalization)  (None, 80, 80, 32)   128         ['Conv1[0][0]']
#
#  Conv1_relu (ReLU)              (None, 80, 80, 32)   0           ['bn_Conv1[0][0]']
#
#  expanded_conv_depthwise (Depth  (None, 80, 80, 32)  288         ['Conv1_relu[0][0]']
#  wiseConv2D)
#
#  expanded_conv_depthwise_BN (Ba  (None, 80, 80, 32)  128         ['expanded_conv_depthwise[0][0]']
#  tchNormalization)
#
#  expanded_conv_depthwise_relu (  (None, 80, 80, 32)  0           ['expanded_conv_depthwise_BN[0][0
#  ReLU)                                                           ]']
#
#  expanded_conv_project (Conv2D)  (None, 80, 80, 16)  512         ['expanded_conv_depthwise_relu[0]
#                                                                  [0]']
#
#  expanded_conv_project_BN (Batc  (None, 80, 80, 16)  64          ['expanded_conv_project[0][0]']
#  hNormalization)
#
#  block_1_expand (Conv2D)        (None, 80, 80, 96)   1536        ['expanded_conv_project_BN[0][0]'
#                                                                  ]
#
#  block_1_expand_BN (BatchNormal  (None, 80, 80, 96)  384         ['block_1_expand[0][0]']
#  ization)
#
#  block_1_expand_relu (ReLU)     (None, 80, 80, 96)   0           ['block_1_expand_BN[0][0]']
#
#  block_1_pad (ZeroPadding2D)    (None, 81, 81, 96)   0           ['block_1_expand_relu[0][0]']
#
#  block_1_depthwise (DepthwiseCo  (None, 40, 40, 96)  864         ['block_1_pad[0][0]']
#  nv2D)
#
#  block_1_depthwise_BN (BatchNor  (None, 40, 40, 96)  384         ['block_1_depthwise[0][0]']
#  malization)
#
#  block_1_depthwise_relu (ReLU)  (None, 40, 40, 96)   0           ['block_1_depthwise_BN[0][0]']
#
#  block_1_project (Conv2D)       (None, 40, 40, 24)   2304        ['block_1_depthwise_relu[0][0]']
#
#  block_1_project_BN (BatchNorma  (None, 40, 40, 24)  96          ['block_1_project[0][0]']
#  lization)
#
#  block_2_expand (Conv2D)        (None, 40, 40, 144)  3456        ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNormal  (None, 40, 40, 144)  576        ['block_2_expand[0][0]']
#  ization)
#
#  block_2_expand_relu (ReLU)     (None, 40, 40, 144)  0           ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (DepthwiseCo  (None, 40, 40, 144)  1296       ['block_2_expand_relu[0][0]']
#  nv2D)
#
#  block_2_depthwise_BN (BatchNor  (None, 40, 40, 144)  576        ['block_2_depthwise[0][0]']
#  malization)
#
#  block_2_depthwise_relu (ReLU)  (None, 40, 40, 144)  0           ['block_2_depthwise_BN[0][0]']
#
#  block_2_project (Conv2D)       (None, 40, 40, 24)   3456        ['block_2_depthwise_relu[0][0]']
#
#  block_2_project_BN (BatchNorma  (None, 40, 40, 24)  96          ['block_2_project[0][0]']
#  lization)
#
#  block_2_add (Add)              (None, 40, 40, 24)   0           ['block_1_project_BN[0][0]',
#                                                                   'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, 40, 40, 144)  3456        ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNormal  (None, 40, 40, 144)  576        ['block_3_expand[0][0]']
#  ization)
#
#  block_3_expand_relu (ReLU)     (None, 40, 40, 144)  0           ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D)    (None, 41, 41, 144)  0           ['block_3_expand_relu[0][0]']
#
#  block_3_depthwise (DepthwiseCo  (None, 20, 20, 144)  1296       ['block_3_pad[0][0]']
#  nv2D)
#
#  block_3_depthwise_BN (BatchNor  (None, 20, 20, 144)  576        ['block_3_depthwise[0][0]']
#  malization)
#
#  block_3_depthwise_relu (ReLU)  (None, 20, 20, 144)  0           ['block_3_depthwise_BN[0][0]']
#
#  block_3_project (Conv2D)       (None, 20, 20, 32)   4608        ['block_3_depthwise_relu[0][0]']
#
#  block_3_project_BN (BatchNorma  (None, 20, 20, 32)  128         ['block_3_project[0][0]']
#  lization)
#
#  block_4_expand (Conv2D)        (None, 20, 20, 192)  6144        ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNormal  (None, 20, 20, 192)  768        ['block_4_expand[0][0]']
#  ization)
#
#  block_4_expand_relu (ReLU)     (None, 20, 20, 192)  0           ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (DepthwiseCo  (None, 20, 20, 192)  1728       ['block_4_expand_relu[0][0]']
#  nv2D)
#
#  block_4_depthwise_BN (BatchNor  (None, 20, 20, 192)  768        ['block_4_depthwise[0][0]']
#  malization)
#
#  block_4_depthwise_relu (ReLU)  (None, 20, 20, 192)  0           ['block_4_depthwise_BN[0][0]']
#
#  block_4_project (Conv2D)       (None, 20, 20, 32)   6144        ['block_4_depthwise_relu[0][0]']
#
#  block_4_project_BN (BatchNorma  (None, 20, 20, 32)  128         ['block_4_project[0][0]']
#  lization)
#
#  block_4_add (Add)              (None, 20, 20, 32)   0           ['block_3_project_BN[0][0]',
#                                                                   'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, 20, 20, 192)  6144        ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNormal  (None, 20, 20, 192)  768        ['block_5_expand[0][0]']
#  ization)
#
#  block_5_expand_relu (ReLU)     (None, 20, 20, 192)  0           ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (DepthwiseCo  (None, 20, 20, 192)  1728       ['block_5_expand_relu[0][0]']
#  nv2D)
#
#  block_5_depthwise_BN (BatchNor  (None, 20, 20, 192)  768        ['block_5_depthwise[0][0]']
#  malization)
#
#  block_5_depthwise_relu (ReLU)  (None, 20, 20, 192)  0           ['block_5_depthwise_BN[0][0]']
#
#  block_5_project (Conv2D)       (None, 20, 20, 32)   6144        ['block_5_depthwise_relu[0][0]']
#
#  block_5_project_BN (BatchNorma  (None, 20, 20, 32)  128         ['block_5_project[0][0]']
#  lization)
#
#  block_5_add (Add)              (None, 20, 20, 32)   0           ['block_4_add[0][0]',
#                                                                   'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, 20, 20, 192)  6144        ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNormal  (None, 20, 20, 192)  768        ['block_6_expand[0][0]']
#  ization)
#
#  block_6_expand_relu (ReLU)     (None, 20, 20, 192)  0           ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D)    (None, 21, 21, 192)  0           ['block_6_expand_relu[0][0]']
#
#  block_6_depthwise (DepthwiseCo  (None, 10, 10, 192)  1728       ['block_6_pad[0][0]']
#  nv2D)
#
#  block_6_depthwise_BN (BatchNor  (None, 10, 10, 192)  768        ['block_6_depthwise[0][0]']
#  malization)
#
#  block_6_depthwise_relu (ReLU)  (None, 10, 10, 192)  0           ['block_6_depthwise_BN[0][0]']
#
#  block_6_project (Conv2D)       (None, 10, 10, 64)   12288       ['block_6_depthwise_relu[0][0]']
#
#  block_6_project_BN (BatchNorma  (None, 10, 10, 64)  256         ['block_6_project[0][0]']
#  lization)
#
#  block_7_expand (Conv2D)        (None, 10, 10, 384)  24576       ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNormal  (None, 10, 10, 384)  1536       ['block_7_expand[0][0]']
#  ization)
#
#  block_7_expand_relu (ReLU)     (None, 10, 10, 384)  0           ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (DepthwiseCo  (None, 10, 10, 384)  3456       ['block_7_expand_relu[0][0]']
#  nv2D)
#
#  block_7_depthwise_BN (BatchNor  (None, 10, 10, 384)  1536       ['block_7_depthwise[0][0]']
#  malization)
#
#  block_7_depthwise_relu (ReLU)  (None, 10, 10, 384)  0           ['block_7_depthwise_BN[0][0]']
#
#  block_7_project (Conv2D)       (None, 10, 10, 64)   24576       ['block_7_depthwise_relu[0][0]']
#
#  block_7_project_BN (BatchNorma  (None, 10, 10, 64)  256         ['block_7_project[0][0]']
#  lization)
#
#  block_7_add (Add)              (None, 10, 10, 64)   0           ['block_6_project_BN[0][0]',
#                                                                   'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, 10, 10, 384)  24576       ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNormal  (None, 10, 10, 384)  1536       ['block_8_expand[0][0]']
#  ization)
#
#  block_8_expand_relu (ReLU)     (None, 10, 10, 384)  0           ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (DepthwiseCo  (None, 10, 10, 384)  3456       ['block_8_expand_relu[0][0]']
#  nv2D)
#
#  block_8_depthwise_BN (BatchNor  (None, 10, 10, 384)  1536       ['block_8_depthwise[0][0]']
#  malization)
#
#  block_8_depthwise_relu (ReLU)  (None, 10, 10, 384)  0           ['block_8_depthwise_BN[0][0]']
#
#  block_8_project (Conv2D)       (None, 10, 10, 64)   24576       ['block_8_depthwise_relu[0][0]']
#
#  block_8_project_BN (BatchNorma  (None, 10, 10, 64)  256         ['block_8_project[0][0]']
#  lization)
#
#  block_8_add (Add)              (None, 10, 10, 64)   0           ['block_7_add[0][0]',
#                                                                   'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, 10, 10, 384)  24576       ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNormal  (None, 10, 10, 384)  1536       ['block_9_expand[0][0]']
#  ization)
#
#  block_9_expand_relu (ReLU)     (None, 10, 10, 384)  0           ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (DepthwiseCo  (None, 10, 10, 384)  3456       ['block_9_expand_relu[0][0]']
#  nv2D)
#
#  block_9_depthwise_BN (BatchNor  (None, 10, 10, 384)  1536       ['block_9_depthwise[0][0]']
#  malization)
#
#  block_9_depthwise_relu (ReLU)  (None, 10, 10, 384)  0           ['block_9_depthwise_BN[0][0]']
#
#  block_9_project (Conv2D)       (None, 10, 10, 64)   24576       ['block_9_depthwise_relu[0][0]']
#
#  block_9_project_BN (BatchNorma  (None, 10, 10, 64)  256         ['block_9_project[0][0]']
#  lization)
#
#  block_9_add (Add)              (None, 10, 10, 64)   0           ['block_8_add[0][0]',
#                                                                   'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, 10, 10, 384)  24576       ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchNorma  (None, 10, 10, 384)  1536       ['block_10_expand[0][0]']
#  lization)
#
#  block_10_expand_relu (ReLU)    (None, 10, 10, 384)  0           ['block_10_expand_BN[0][0]']
#
#  block_10_depthwise (DepthwiseC  (None, 10, 10, 384)  3456       ['block_10_expand_relu[0][0]']
#  onv2D)
#
#  block_10_depthwise_BN (BatchNo  (None, 10, 10, 384)  1536       ['block_10_depthwise[0][0]']
#  rmalization)
#
#  block_10_depthwise_relu (ReLU)  (None, 10, 10, 384)  0          ['block_10_depthwise_BN[0][0]']
#
#  block_10_project (Conv2D)      (None, 10, 10, 96)   36864       ['block_10_depthwise_relu[0][0]']
#
#  block_10_project_BN (BatchNorm  (None, 10, 10, 96)  384         ['block_10_project[0][0]']
#  alization)
#
#  block_11_expand (Conv2D)       (None, 10, 10, 576)  55296       ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchNorma  (None, 10, 10, 576)  2304       ['block_11_expand[0][0]']
#  lization)
#
#  block_11_expand_relu (ReLU)    (None, 10, 10, 576)  0           ['block_11_expand_BN[0][0]']
#
#  block_11_depthwise (DepthwiseC  (None, 10, 10, 576)  5184       ['block_11_expand_relu[0][0]']
#  onv2D)
#
#  block_11_depthwise_BN (BatchNo  (None, 10, 10, 576)  2304       ['block_11_depthwise[0][0]']
#  rmalization)
#
#  block_11_depthwise_relu (ReLU)  (None, 10, 10, 576)  0          ['block_11_depthwise_BN[0][0]']
#
#  block_11_project (Conv2D)      (None, 10, 10, 96)   55296       ['block_11_depthwise_relu[0][0]']
#
#  block_11_project_BN (BatchNorm  (None, 10, 10, 96)  384         ['block_11_project[0][0]']
#  alization)
#
#  block_11_add (Add)             (None, 10, 10, 96)   0           ['block_10_project_BN[0][0]',
#                                                                   'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, 10, 10, 576)  55296       ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchNorma  (None, 10, 10, 576)  2304       ['block_12_expand[0][0]']
#  lization)
#
#  block_12_expand_relu (ReLU)    (None, 10, 10, 576)  0           ['block_12_expand_BN[0][0]']
#
#  block_12_depthwise (DepthwiseC  (None, 10, 10, 576)  5184       ['block_12_expand_relu[0][0]']
#  onv2D)
#
#  block_12_depthwise_BN (BatchNo  (None, 10, 10, 576)  2304       ['block_12_depthwise[0][0]']
#  rmalization)
#
#  block_12_depthwise_relu (ReLU)  (None, 10, 10, 576)  0          ['block_12_depthwise_BN[0][0]']
#
#  block_12_project (Conv2D)      (None, 10, 10, 96)   55296       ['block_12_depthwise_relu[0][0]']
#
#  block_12_project_BN (BatchNorm  (None, 10, 10, 96)  384         ['block_12_project[0][0]']
#  alization)
#
#  block_12_add (Add)             (None, 10, 10, 96)   0           ['block_11_add[0][0]',
#                                                                   'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, 10, 10, 576)  55296       ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchNorma  (None, 10, 10, 576)  2304       ['block_13_expand[0][0]']
#  lization)
#
#  block_13_expand_relu (ReLU)    (None, 10, 10, 576)  0           ['block_13_expand_BN[0][0]']
#
#  block_13_pad (ZeroPadding2D)   (None, 11, 11, 576)  0           ['block_13_expand_relu[0][0]']
#
#  block_13_depthwise (DepthwiseC  (None, 5, 5, 576)   5184        ['block_13_pad[0][0]']
#  onv2D)
#
#  block_13_depthwise_BN (BatchNo  (None, 5, 5, 576)   2304        ['block_13_depthwise[0][0]']
#  rmalization)
#
#  block_13_depthwise_relu (ReLU)  (None, 5, 5, 576)   0           ['block_13_depthwise_BN[0][0]']
#
#  block_13_project (Conv2D)      (None, 5, 5, 160)    92160       ['block_13_depthwise_relu[0][0]']
#
#  block_13_project_BN (BatchNorm  (None, 5, 5, 160)   640         ['block_13_project[0][0]']
#  alization)
#
#  block_14_expand (Conv2D)       (None, 5, 5, 960)    153600      ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchNorma  (None, 5, 5, 960)   3840        ['block_14_expand[0][0]']
#  lization)
#
#  block_14_expand_relu (ReLU)    (None, 5, 5, 960)    0           ['block_14_expand_BN[0][0]']
#
#  block_14_depthwise (DepthwiseC  (None, 5, 5, 960)   8640        ['block_14_expand_relu[0][0]']
#  onv2D)
#
#  block_14_depthwise_BN (BatchNo  (None, 5, 5, 960)   3840        ['block_14_depthwise[0][0]']
#  rmalization)
#
#  block_14_depthwise_relu (ReLU)  (None, 5, 5, 960)   0           ['block_14_depthwise_BN[0][0]']
#
#  block_14_project (Conv2D)      (None, 5, 5, 160)    153600      ['block_14_depthwise_relu[0][0]']
#
#  block_14_project_BN (BatchNorm  (None, 5, 5, 160)   640         ['block_14_project[0][0]']
#  alization)
#
#  block_14_add (Add)             (None, 5, 5, 160)    0           ['block_13_project_BN[0][0]',
#                                                                   'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, 5, 5, 960)    153600      ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchNorma  (None, 5, 5, 960)   3840        ['block_15_expand[0][0]']
#  lization)
#
#  block_15_expand_relu (ReLU)    (None, 5, 5, 960)    0           ['block_15_expand_BN[0][0]']
#
#  block_15_depthwise (DepthwiseC  (None, 5, 5, 960)   8640        ['block_15_expand_relu[0][0]']
#  onv2D)
#
#  block_15_depthwise_BN (BatchNo  (None, 5, 5, 960)   3840        ['block_15_depthwise[0][0]']
#  rmalization)
#
#  block_15_depthwise_relu (ReLU)  (None, 5, 5, 960)   0           ['block_15_depthwise_BN[0][0]']
#
#  block_15_project (Conv2D)      (None, 5, 5, 160)    153600      ['block_15_depthwise_relu[0][0]']
#
#  block_15_project_BN (BatchNorm  (None, 5, 5, 160)   640         ['block_15_project[0][0]']
#  alization)
#
#  block_15_add (Add)             (None, 5, 5, 160)    0           ['block_14_add[0][0]',
#                                                                   'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, 5, 5, 960)    153600      ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchNorma  (None, 5, 5, 960)   3840        ['block_16_expand[0][0]']
#  lization)
#
#  block_16_expand_relu (ReLU)    (None, 5, 5, 960)    0           ['block_16_expand_BN[0][0]']
#
#  block_16_depthwise (DepthwiseC  (None, 5, 5, 960)   8640        ['block_16_expand_relu[0][0]']
#  onv2D)
#
#  block_16_depthwise_BN (BatchNo  (None, 5, 5, 960)   3840        ['block_16_depthwise[0][0]']
#  rmalization)
#
#  block_16_depthwise_relu (ReLU)  (None, 5, 5, 960)   0           ['block_16_depthwise_BN[0][0]']
#
#  block_16_project (Conv2D)      (None, 5, 5, 320)    307200      ['block_16_depthwise_relu[0][0]']
#
#  block_16_project_BN (BatchNorm  (None, 5, 5, 320)   1280        ['block_16_project[0][0]']
#  alization)
#
#  Conv_1 (Conv2D)                (None, 5, 5, 1280)   409600      ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalization)  (None, 5, 5, 1280)  5120        ['Conv_1[0][0]']
#
#  out_relu (ReLU)                (None, 5, 5, 1280)   0           ['Conv_1_bn[0][0]']
#
#  flatten (Flatten)              (None, 32000)        0           ['out_relu[0][0]']
#
#  dropout (Dropout)              (None, 32000)        0           ['flatten[0][0]']
#
#  dense (Dense)                  (None, 8)            256008      ['dropout[0][0]']
#
#  dense_1 (Dense)                (None, 1)            9           ['dense[0][0]']
#
# ==================================================================================================
# Total params: 2,514,001
# Trainable params: 256,017
# Non-trainable params: 2,257,984
# __________________________________________________________________________________________________

# %%
# tell the model what cost and optimization method to use
model.compile(
  loss='binary_crossentropy',
  optimizer=Adam(
    learning_rate=0.000001,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07
),
  metrics=['accuracy']
)

# %%
import os
os.mkdir('/content/model_weights/')

# %%
model_checkpoint = ModelCheckpoint('./model_weights/finalyearproject_antispoofing_model_{epoch:02d}-{val_accuracy:.6f}.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True )

# %%
history = model.fit_generator(
    train_generator,
    steps_per_epoch = train_generator.samples // 25,
    validation_data = valid_generator, 
    validation_steps = valid_generator.samples // 25,
    epochs = 100,
    callbacks=[model_checkpoint])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   import sys
# Epoch 1/100
# 168/168 [==============================] - ETA: 0s - loss: 0.7007 - accuracy: 0.5592
# Epoch 1: val_loss improved from inf to 0.66746, saving model to ./model_weights/finalyearproject_antispoofing_model_01-0.608421.h5
# 168/168 [==============================] - 129s 739ms/step - loss: 0.7007 - accuracy: 0.5592 - val_loss: 0.6675 - val_accuracy: 0.6084
# Epoch 2/100
# 168/168 [==============================] - ETA: 0s - loss: 0.6675 - accuracy: 0.6031
# Epoch 2: val_loss improved from 0.66746 to 0.63870, saving model to ./model_weights/finalyearproject_antispoofing_model_02-0.657895.h5
# 168/168 [==============================] - 111s 661ms/step - loss: 0.6675 - accuracy: 0.6031 - val_loss: 0.6387 - val_accuracy: 0.6579
# Epoch 3/100
# 168/168 [==============================] - ETA: 0s - loss: 0.6361 - accuracy: 0.6498
# Epoch 3: val_loss improved from 0.63870 to 0.61333, saving model to ./model_weights/finalyearproject_antispoofing_model_03-0.691579.h5
# 168/168 [==============================] - 116s 692ms/step - loss: 0.6361 - accuracy: 0.6498 - val_loss: 0.6133 - val_accuracy: 0.6916
# Epoch 4/100
# 168/168 [==============================] - ETA: 0s - loss: 0.6087 - accuracy: 0.6958
# Epoch 4: val_loss improved from 0.61333 to 0.58276, saving model to ./model_weights/finalyearproject_antispoofing_model_04-0.724211.h5
# 168/168 [==============================] - 110s 657ms/step - loss: 0.6087 - accuracy: 0.6958 - val_loss: 0.5828 - val_accuracy: 0.7242
# Epoch 5/100
# 168/168 [==============================] - ETA: 0s - loss: 0.5778 - accuracy: 0.7294
# Epoch 5: val_loss improved from 0.58276 to 0.55077, saving model to ./model_weights/finalyearproject_antispoofing_model_05-0.750526.h5
# 168/168 [==============================] - 112s 668ms/step - loss: 0.5778 - accuracy: 0.7294 - val_loss: 0.5508 - val_accuracy: 0.7505
# Epoch 6/100
# 168/168 [==============================] - ETA: 0s - loss: 0.5450 - accuracy: 0.7573
# Epoch 6: val_loss improved from 0.55077 to 0.52420, saving model to ./model_weights/finalyearproject_antispoofing_model_06-0.765263.h5
# 168/168 [==============================] - 112s 669ms/step - loss: 0.5450 - accuracy: 0.7573 - val_loss: 0.5242 - val_accuracy: 0.7653
# Epoch 7/100
# 168/168 [==============================] - ETA: 0s - loss: 0.5087 - accuracy: 0.7933
# Epoch 7: val_loss improved from 0.52420 to 0.49249, saving model to ./model_weights/finalyearproject_antispoofing_model_07-0.788421.h5
# 168/168 [==============================] - 114s 677ms/step - loss: 0.5087 - accuracy: 0.7933 - val_loss: 0.4925 - val_accuracy: 0.7884
# Epoch 8/100
# 168/168 [==============================] - ETA: 0s - loss: 0.4888 - accuracy: 0.7952
# Epoch 8: val_loss improved from 0.49249 to 0.46828, saving model to ./model_weights/finalyearproject_antispoofing_model_08-0.802105.h5
# 168/168 [==============================] - 109s 648ms/step - loss: 0.4888 - accuracy: 0.7952 - val_loss: 0.4683 - val_accuracy: 0.8021
# Epoch 9/100
# 168/168 [==============================] - ETA: 0s - loss: 0.4596 - accuracy: 0.8164
# Epoch 9: val_loss improved from 0.46828 to 0.44291, saving model to ./model_weights/finalyearproject_antispoofing_model_09-0.817895.h5
# 168/168 [==============================] - 114s 674ms/step - loss: 0.4596 - accuracy: 0.8164 - val_loss: 0.4429 - val_accuracy: 0.8179
# Epoch 10/100
# 168/168 [==============================] - ETA: 0s - loss: 0.4349 - accuracy: 0.8348
# Epoch 10: val_loss improved from 0.44291 to 0.42283, saving model to ./model_weights/finalyearproject_antispoofing_model_10-0.822105.h5
# 168/168 [==============================] - 112s 664ms/step - loss: 0.4349 - accuracy: 0.8348 - val_loss: 0.4228 - val_accuracy: 0.8221
# Epoch 11/100
# 168/168 [==============================] - ETA: 0s - loss: 0.4115 - accuracy: 0.8400
# Epoch 11: val_loss improved from 0.42283 to 0.40623, saving model to ./model_weights/finalyearproject_antispoofing_model_11-0.826316.h5
# 168/168 [==============================] - 112s 664ms/step - loss: 0.4115 - accuracy: 0.8400 - val_loss: 0.4062 - val_accuracy: 0.8263
# Epoch 12/100
# 168/168 [==============================] - ETA: 0s - loss: 0.3856 - accuracy: 0.8560
# Epoch 12: val_loss improved from 0.40623 to 0.39045, saving model to ./model_weights/finalyearproject_antispoofing_model_12-0.832632.h5
# 168/168 [==============================] - 112s 666ms/step - loss: 0.3856 - accuracy: 0.8560 - val_loss: 0.3904 - val_accuracy: 0.8326
# Epoch 13/100
# 168/168 [==============================] - ETA: 0s - loss: 0.3608 - accuracy: 0.8749
# Epoch 13: val_loss improved from 0.39045 to 0.37494, saving model to ./model_weights/finalyearproject_antispoofing_model_13-0.836842.h5
# 168/168 [==============================] - 114s 679ms/step - loss: 0.3608 - accuracy: 0.8749 - val_loss: 0.3749 - val_accuracy: 0.8368
# Epoch 14/100
# 168/168 [==============================] - ETA: 0s - loss: 0.3562 - accuracy: 0.8663
# Epoch 14: val_loss improved from 0.37494 to 0.35684, saving model to ./model_weights/finalyearproject_antispoofing_model_14-0.845263.h5
# 168/168 [==============================] - 112s 664ms/step - loss: 0.3562 - accuracy: 0.8663 - val_loss: 0.3568 - val_accuracy: 0.8453
# Epoch 15/100
# 168/168 [==============================] - ETA: 0s - loss: 0.3431 - accuracy: 0.8772
# Epoch 15: val_loss improved from 0.35684 to 0.34238, saving model to ./model_weights/finalyearproject_antispoofing_model_15-0.848421.h5
# 168/168 [==============================] - 112s 664ms/step - loss: 0.3431 - accuracy: 0.8772 - val_loss: 0.3424 - val_accuracy: 0.8484
# Epoch 16/100
# 168/168 [==============================] - ETA: 0s - loss: 0.3308 - accuracy: 0.8763
# Epoch 16: val_loss improved from 0.34238 to 0.32897, saving model to ./model_weights/finalyearproject_antispoofing_model_16-0.856842.h5
# 168/168 [==============================] - 112s 669ms/step - loss: 0.3308 - accuracy: 0.8763 - val_loss: 0.3290 - val_accuracy: 0.8568
# Epoch 17/100
# 168/168 [==============================] - ETA: 0s - loss: 0.3248 - accuracy: 0.8844
# Epoch 17: val_loss improved from 0.32897 to 0.32100, saving model to ./model_weights/finalyearproject_antispoofing_model_17-0.861053.h5
# 168/168 [==============================] - 117s 695ms/step - loss: 0.3248 - accuracy: 0.8844 - val_loss: 0.3210 - val_accuracy: 0.8611
# Epoch 18/100
# 168/168 [==============================] - ETA: 0s - loss: 0.3091 - accuracy: 0.8901
# Epoch 18: val_loss improved from 0.32100 to 0.30568, saving model to ./model_weights/finalyearproject_antispoofing_model_18-0.873684.h5
# 168/168 [==============================] - 113s 673ms/step - loss: 0.3091 - accuracy: 0.8901 - val_loss: 0.3057 - val_accuracy: 0.8737
# Epoch 19/100
# 168/168 [==============================] - ETA: 0s - loss: 0.3023 - accuracy: 0.8925
# Epoch 19: val_loss improved from 0.30568 to 0.29930, saving model to ./model_weights/finalyearproject_antispoofing_model_19-0.875789.h5
# 168/168 [==============================] - 113s 671ms/step - loss: 0.3023 - accuracy: 0.8925 - val_loss: 0.2993 - val_accuracy: 0.8758
# Epoch 20/100
# 168/168 [==============================] - ETA: 0s - loss: 0.2948 - accuracy: 0.9008
# Epoch 20: val_loss improved from 0.29930 to 0.29248, saving model to ./model_weights/finalyearproject_antispoofing_model_20-0.877895.h5
# 168/168 [==============================] - 117s 694ms/step - loss: 0.2948 - accuracy: 0.9008 - val_loss: 0.2925 - val_accuracy: 0.8779
# Epoch 21/100
# 168/168 [==============================] - ETA: 0s - loss: 0.2867 - accuracy: 0.8989
# Epoch 21: val_loss improved from 0.29248 to 0.28568, saving model to ./model_weights/finalyearproject_antispoofing_model_21-0.881053.h5
# 168/168 [==============================] - 113s 670ms/step - loss: 0.2867 - accuracy: 0.8989 - val_loss: 0.2857 - val_accuracy: 0.8811
# Epoch 22/100
# 168/168 [==============================] - ETA: 0s - loss: 0.2766 - accuracy: 0.9020
# Epoch 22: val_loss improved from 0.28568 to 0.27827, saving model to ./model_weights/finalyearproject_antispoofing_model_22-0.882105.h5
# 168/168 [==============================] - 113s 672ms/step - loss: 0.2766 - accuracy: 0.9020 - val_loss: 0.2783 - val_accuracy: 0.8821
# Epoch 23/100
# 168/168 [==============================] - ETA: 0s - loss: 0.2681 - accuracy: 0.9066
# Epoch 23: val_loss improved from 0.27827 to 0.27218, saving model to ./model_weights/finalyearproject_antispoofing_model_23-0.883158.h5
# 168/168 [==============================] - 120s 711ms/step - loss: 0.2681 - accuracy: 0.9066 - val_loss: 0.2722 - val_accuracy: 0.8832
# Epoch 24/100
# 168/168 [==============================] - ETA: 0s - loss: 0.2652 - accuracy: 0.9061
# Epoch 24: val_loss improved from 0.27218 to 0.25885, saving model to ./model_weights/finalyearproject_antispoofing_model_24-0.890526.h5
# 168/168 [==============================] - 126s 751ms/step - loss: 0.2652 - accuracy: 0.9061 - val_loss: 0.2589 - val_accuracy: 0.8905
# Epoch 25/100
# 168/168 [==============================] - ETA: 0s - loss: 0.2519 - accuracy: 0.9178
# Epoch 25: val_loss improved from 0.25885 to 0.25811, saving model to ./model_weights/finalyearproject_antispoofing_model_25-0.890526.h5
# 168/168 [==============================] - 122s 728ms/step - loss: 0.2519 - accuracy: 0.9178 - val_loss: 0.2581 - val_accuracy: 0.8905
# Epoch 26/100
# 168/168 [==============================] - ETA: 0s - loss: 0.2479 - accuracy: 0.9161
# Epoch 26: val_loss did not improve from 0.25811
# 168/168 [==============================] - 127s 754ms/step - loss: 0.2479 - accuracy: 0.9161 - val_loss: 0.2594 - val_accuracy: 0.8853
# Epoch 27/100
# 168/168 [==============================] - ETA: 0s - loss: 0.2425 - accuracy: 0.9223
# Epoch 27: val_loss improved from 0.25811 to 0.25389, saving model to ./model_weights/finalyearproject_antispoofing_model_27-0.890526.h5
# 168/168 [==============================] - 120s 711ms/step - loss: 0.2425 - accuracy: 0.9223 - val_loss: 0.2539 - val_accuracy: 0.8905
# Epoch 28/100
# 168/168 [==============================] - ETA: 0s - loss: 0.2424 - accuracy: 0.9170
# Epoch 28: val_loss improved from 0.25389 to 0.24431, saving model to ./model_weights/finalyearproject_antispoofing_model_28-0.896842.h5
# 168/168 [==============================] - 124s 737ms/step - loss: 0.2424 - accuracy: 0.9170 - val_loss: 0.2443 - val_accuracy: 0.8968
# Epoch 29/100
# 168/168 [==============================] - ETA: 0s - loss: 0.2310 - accuracy: 0.9244
# Epoch 29: val_loss improved from 0.24431 to 0.23737, saving model to ./model_weights/finalyearproject_antispoofing_model_29-0.897895.h5
# 168/168 [==============================] - 127s 757ms/step - loss: 0.2310 - accuracy: 0.9244 - val_loss: 0.2374 - val_accuracy: 0.8979
# Epoch 30/100
# 168/168 [==============================] - ETA: 0s - loss: 0.2380 - accuracy: 0.9147
# Epoch 30: val_loss improved from 0.23737 to 0.22945, saving model to ./model_weights/finalyearproject_antispoofing_model_30-0.901053.h5
# 168/168 [==============================] - 124s 737ms/step - loss: 0.2380 - accuracy: 0.9147 - val_loss: 0.2295 - val_accuracy: 0.9011
# Epoch 31/100
# 168/168 [==============================] - ETA: 0s - loss: 0.2281 - accuracy: 0.9228
# Epoch 31: val_loss did not improve from 0.22945
# 168/168 [==============================] - 117s 695ms/step - loss: 0.2281 - accuracy: 0.9228 - val_loss: 0.2301 - val_accuracy: 0.8989
# Epoch 32/100
# 168/168 [==============================] - ETA: 0s - loss: 0.2214 - accuracy: 0.9266
# Epoch 32: val_loss did not improve from 0.22945
# 168/168 [==============================] - 119s 706ms/step - loss: 0.2214 - accuracy: 0.9266 - val_loss: 0.2295 - val_accuracy: 0.8989
# Epoch 33/100
# 168/168 [==============================] - ETA: 0s - loss: 0.2158 - accuracy: 0.9249
# Epoch 33: val_loss improved from 0.22945 to 0.22061, saving model to ./model_weights/finalyearproject_antispoofing_model_33-0.904211.h5
# 168/168 [==============================] - 116s 693ms/step - loss: 0.2158 - accuracy: 0.9249 - val_loss: 0.2206 - val_accuracy: 0.9042
# Epoch 34/100
# 168/168 [==============================] - ETA: 0s - loss: 0.2113 - accuracy: 0.9328
# Epoch 34: val_loss improved from 0.22061 to 0.21854, saving model to ./model_weights/finalyearproject_antispoofing_model_34-0.905263.h5
# 168/168 [==============================] - 117s 697ms/step - loss: 0.2113 - accuracy: 0.9328 - val_loss: 0.2185 - val_accuracy: 0.9053
# Epoch 35/100
# 168/168 [==============================] - ETA: 0s - loss: 0.2163 - accuracy: 0.9232
# Epoch 35: val_loss improved from 0.21854 to 0.20918, saving model to ./model_weights/finalyearproject_antispoofing_model_35-0.906316.h5
# 168/168 [==============================] - 129s 768ms/step - loss: 0.2163 - accuracy: 0.9232 - val_loss: 0.2092 - val_accuracy: 0.9063
# Epoch 36/100
# 168/168 [==============================] - ETA: 0s - loss: 0.2008 - accuracy: 0.9342
# Epoch 36: val_loss did not improve from 0.20918
# 168/168 [==============================] - 129s 763ms/step - loss: 0.2008 - accuracy: 0.9342 - val_loss: 0.2136 - val_accuracy: 0.9063
# Epoch 37/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1998 - accuracy: 0.9348
# Epoch 37: val_loss did not improve from 0.20918
# 168/168 [==============================] - 120s 716ms/step - loss: 0.1998 - accuracy: 0.9348 - val_loss: 0.2164 - val_accuracy: 0.9032
# Epoch 38/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1986 - accuracy: 0.9340
# Epoch 38: val_loss improved from 0.20918 to 0.20122, saving model to ./model_weights/finalyearproject_antispoofing_model_38-0.909474.h5
# 168/168 [==============================] - 119s 710ms/step - loss: 0.1986 - accuracy: 0.9340 - val_loss: 0.2012 - val_accuracy: 0.9095
# Epoch 39/100
# 168/168 [==============================] - ETA: 0s - loss: 0.2025 - accuracy: 0.9292
# Epoch 39: val_loss did not improve from 0.20122
# 168/168 [==============================] - 114s 678ms/step - loss: 0.2025 - accuracy: 0.9292 - val_loss: 0.2040 - val_accuracy: 0.9074
# Epoch 40/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1940 - accuracy: 0.9352
# Epoch 40: val_loss improved from 0.20122 to 0.19352, saving model to ./model_weights/finalyearproject_antispoofing_model_40-0.914737.h5
# 168/168 [==============================] - 114s 677ms/step - loss: 0.1940 - accuracy: 0.9352 - val_loss: 0.1935 - val_accuracy: 0.9147
# Epoch 41/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1884 - accuracy: 0.9406
# Epoch 41: val_loss improved from 0.19352 to 0.19075, saving model to ./model_weights/finalyearproject_antispoofing_model_41-0.915789.h5
# 168/168 [==============================] - 113s 672ms/step - loss: 0.1884 - accuracy: 0.9406 - val_loss: 0.1908 - val_accuracy: 0.9158
# Epoch 42/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1894 - accuracy: 0.9414
# Epoch 42: val_loss improved from 0.19075 to 0.19056, saving model to ./model_weights/finalyearproject_antispoofing_model_42-0.915789.h5
# 168/168 [==============================] - 115s 682ms/step - loss: 0.1894 - accuracy: 0.9414 - val_loss: 0.1906 - val_accuracy: 0.9158
# Epoch 43/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1853 - accuracy: 0.9402
# Epoch 43: val_loss improved from 0.19056 to 0.18621, saving model to ./model_weights/finalyearproject_antispoofing_model_43-0.917895.h5
# 168/168 [==============================] - 112s 663ms/step - loss: 0.1853 - accuracy: 0.9402 - val_loss: 0.1862 - val_accuracy: 0.9179
# Epoch 44/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1843 - accuracy: 0.9395
# Epoch 44: val_loss improved from 0.18621 to 0.18235, saving model to ./model_weights/finalyearproject_antispoofing_model_44-0.920000.h5
# 168/168 [==============================] - 115s 685ms/step - loss: 0.1843 - accuracy: 0.9395 - val_loss: 0.1823 - val_accuracy: 0.9200
# Epoch 45/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1837 - accuracy: 0.9390
# Epoch 45: val_loss improved from 0.18235 to 0.18211, saving model to ./model_weights/finalyearproject_antispoofing_model_45-0.918947.h5
# 168/168 [==============================] - 113s 674ms/step - loss: 0.1837 - accuracy: 0.9390 - val_loss: 0.1821 - val_accuracy: 0.9189
# Epoch 46/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1848 - accuracy: 0.9386
# Epoch 46: val_loss improved from 0.18211 to 0.17885, saving model to ./model_weights/finalyearproject_antispoofing_model_46-0.920000.h5
# 168/168 [==============================] - 112s 668ms/step - loss: 0.1848 - accuracy: 0.9386 - val_loss: 0.1788 - val_accuracy: 0.9200
# Epoch 47/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1702 - accuracy: 0.9511
# Epoch 47: val_loss did not improve from 0.17885
# 168/168 [==============================] - 114s 680ms/step - loss: 0.1702 - accuracy: 0.9511 - val_loss: 0.1798 - val_accuracy: 0.9168
# Epoch 48/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1760 - accuracy: 0.9452
# Epoch 48: val_loss improved from 0.17885 to 0.16958, saving model to ./model_weights/finalyearproject_antispoofing_model_48-0.924211.h5
# 168/168 [==============================] - 118s 701ms/step - loss: 0.1760 - accuracy: 0.9452 - val_loss: 0.1696 - val_accuracy: 0.9242
# Epoch 49/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1700 - accuracy: 0.9499
# Epoch 49: val_loss did not improve from 0.16958
# 168/168 [==============================] - 104s 618ms/step - loss: 0.1700 - accuracy: 0.9499 - val_loss: 0.1723 - val_accuracy: 0.9211
# Epoch 50/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1617 - accuracy: 0.9478
# Epoch 50: val_loss did not improve from 0.16958
# 168/168 [==============================] - 105s 622ms/step - loss: 0.1617 - accuracy: 0.9478 - val_loss: 0.1698 - val_accuracy: 0.9232
# Epoch 51/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1674 - accuracy: 0.9473
# Epoch 51: val_loss improved from 0.16958 to 0.16805, saving model to ./model_weights/finalyearproject_antispoofing_model_51-0.924211.h5
# 168/168 [==============================] - 106s 633ms/step - loss: 0.1674 - accuracy: 0.9473 - val_loss: 0.1680 - val_accuracy: 0.9242
# Epoch 52/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1642 - accuracy: 0.9454
# Epoch 52: val_loss improved from 0.16805 to 0.16526, saving model to ./model_weights/finalyearproject_antispoofing_model_52-0.926316.h5
# 168/168 [==============================] - 107s 636ms/step - loss: 0.1642 - accuracy: 0.9454 - val_loss: 0.1653 - val_accuracy: 0.9263
# Epoch 53/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1633 - accuracy: 0.9468
# Epoch 53: val_loss improved from 0.16526 to 0.15937, saving model to ./model_weights/finalyearproject_antispoofing_model_53-0.928421.h5
# 168/168 [==============================] - 107s 639ms/step - loss: 0.1633 - accuracy: 0.9468 - val_loss: 0.1594 - val_accuracy: 0.9284
# Epoch 54/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1651 - accuracy: 0.9456
# Epoch 54: val_loss did not improve from 0.15937
# 168/168 [==============================] - 107s 639ms/step - loss: 0.1651 - accuracy: 0.9456 - val_loss: 0.1626 - val_accuracy: 0.9263
# Epoch 55/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1592 - accuracy: 0.9447
# Epoch 55: val_loss improved from 0.15937 to 0.15648, saving model to ./model_weights/finalyearproject_antispoofing_model_55-0.929474.h5
# 168/168 [==============================] - 106s 629ms/step - loss: 0.1592 - accuracy: 0.9447 - val_loss: 0.1565 - val_accuracy: 0.9295
# Epoch 56/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1565 - accuracy: 0.9504
# Epoch 56: val_loss improved from 0.15648 to 0.14857, saving model to ./model_weights/finalyearproject_antispoofing_model_56-0.934737.h5
# 168/168 [==============================] - 109s 649ms/step - loss: 0.1565 - accuracy: 0.9504 - val_loss: 0.1486 - val_accuracy: 0.9347
# Epoch 57/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1517 - accuracy: 0.9504
# Epoch 57: val_loss did not improve from 0.14857
# 168/168 [==============================] - 108s 644ms/step - loss: 0.1517 - accuracy: 0.9504 - val_loss: 0.1531 - val_accuracy: 0.9316
# Epoch 58/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1511 - accuracy: 0.9521
# Epoch 58: val_loss did not improve from 0.14857
# 168/168 [==============================] - 107s 635ms/step - loss: 0.1511 - accuracy: 0.9521 - val_loss: 0.1492 - val_accuracy: 0.9347
# Epoch 59/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1527 - accuracy: 0.9507
# Epoch 59: val_loss did not improve from 0.14857
# 168/168 [==============================] - 104s 621ms/step - loss: 0.1527 - accuracy: 0.9507 - val_loss: 0.1606 - val_accuracy: 0.9253
# Epoch 60/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1429 - accuracy: 0.9533
# Epoch 60: val_loss improved from 0.14857 to 0.14497, saving model to ./model_weights/finalyearproject_antispoofing_model_60-0.937895.h5
# 168/168 [==============================] - 108s 644ms/step - loss: 0.1429 - accuracy: 0.9533 - val_loss: 0.1450 - val_accuracy: 0.9379
# Epoch 61/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1461 - accuracy: 0.9549
# Epoch 61: val_loss did not improve from 0.14497
# 168/168 [==============================] - 114s 680ms/step - loss: 0.1461 - accuracy: 0.9549 - val_loss: 0.1530 - val_accuracy: 0.9337
# Epoch 62/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1516 - accuracy: 0.9516
# Epoch 62: val_loss improved from 0.14497 to 0.14270, saving model to ./model_weights/finalyearproject_antispoofing_model_62-0.938947.h5
# 168/168 [==============================] - 109s 649ms/step - loss: 0.1516 - accuracy: 0.9516 - val_loss: 0.1427 - val_accuracy: 0.9389
# Epoch 63/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1412 - accuracy: 0.9540
# Epoch 63: val_loss improved from 0.14270 to 0.14267, saving model to ./model_weights/finalyearproject_antispoofing_model_63-0.938947.h5
# 168/168 [==============================] - 103s 611ms/step - loss: 0.1412 - accuracy: 0.9540 - val_loss: 0.1427 - val_accuracy: 0.9389
# Epoch 64/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1415 - accuracy: 0.9559
# Epoch 64: val_loss improved from 0.14267 to 0.13792, saving model to ./model_weights/finalyearproject_antispoofing_model_64-0.941053.h5
# 168/168 [==============================] - 107s 638ms/step - loss: 0.1415 - accuracy: 0.9559 - val_loss: 0.1379 - val_accuracy: 0.9411
# Epoch 65/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1365 - accuracy: 0.9571
# Epoch 65: val_loss improved from 0.13792 to 0.13670, saving model to ./model_weights/finalyearproject_antispoofing_model_65-0.942105.h5
# 168/168 [==============================] - 115s 686ms/step - loss: 0.1365 - accuracy: 0.9571 - val_loss: 0.1367 - val_accuracy: 0.9421
# Epoch 66/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1386 - accuracy: 0.9580
# Epoch 66: val_loss did not improve from 0.13670
# 168/168 [==============================] - 113s 672ms/step - loss: 0.1386 - accuracy: 0.9580 - val_loss: 0.1371 - val_accuracy: 0.9432
# Epoch 67/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1374 - accuracy: 0.9523
# Epoch 67: val_loss improved from 0.13670 to 0.13415, saving model to ./model_weights/finalyearproject_antispoofing_model_67-0.943158.h5
# 168/168 [==============================] - 105s 624ms/step - loss: 0.1374 - accuracy: 0.9523 - val_loss: 0.1341 - val_accuracy: 0.9432
# Epoch 68/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1426 - accuracy: 0.9545
# Epoch 68: val_loss improved from 0.13415 to 0.13386, saving model to ./model_weights/finalyearproject_antispoofing_model_68-0.943158.h5
# 168/168 [==============================] - 107s 636ms/step - loss: 0.1426 - accuracy: 0.9545 - val_loss: 0.1339 - val_accuracy: 0.9432
# Epoch 69/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1405 - accuracy: 0.9549
# Epoch 69: val_loss improved from 0.13386 to 0.13280, saving model to ./model_weights/finalyearproject_antispoofing_model_69-0.943158.h5
# 168/168 [==============================] - 112s 665ms/step - loss: 0.1405 - accuracy: 0.9549 - val_loss: 0.1328 - val_accuracy: 0.9432
# Epoch 70/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1384 - accuracy: 0.9561
# Epoch 70: val_loss did not improve from 0.13280
# 168/168 [==============================] - 107s 633ms/step - loss: 0.1384 - accuracy: 0.9561 - val_loss: 0.1339 - val_accuracy: 0.9421
# Epoch 71/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1384 - accuracy: 0.9557
# Epoch 71: val_loss improved from 0.13280 to 0.12881, saving model to ./model_weights/finalyearproject_antispoofing_model_71-0.944211.h5
# 168/168 [==============================] - 105s 626ms/step - loss: 0.1384 - accuracy: 0.9557 - val_loss: 0.1288 - val_accuracy: 0.9442
# Epoch 72/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1324 - accuracy: 0.9588
# Epoch 72: val_loss improved from 0.12881 to 0.12560, saving model to ./model_weights/finalyearproject_antispoofing_model_72-0.948421.h5
# 168/168 [==============================] - 109s 644ms/step - loss: 0.1324 - accuracy: 0.9588 - val_loss: 0.1256 - val_accuracy: 0.9484
# Epoch 73/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1314 - accuracy: 0.9571
# Epoch 73: val_loss improved from 0.12560 to 0.12536, saving model to ./model_weights/finalyearproject_antispoofing_model_73-0.947368.h5
# 168/168 [==============================] - 109s 648ms/step - loss: 0.1314 - accuracy: 0.9571 - val_loss: 0.1254 - val_accuracy: 0.9474
# Epoch 74/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1311 - accuracy: 0.9585
# Epoch 74: val_loss did not improve from 0.12536
# 168/168 [==============================] - 110s 653ms/step - loss: 0.1311 - accuracy: 0.9585 - val_loss: 0.1281 - val_accuracy: 0.9463
# Epoch 75/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1362 - accuracy: 0.9526
# Epoch 75: val_loss did not improve from 0.12536
# 168/168 [==============================] - 106s 631ms/step - loss: 0.1362 - accuracy: 0.9526 - val_loss: 0.1256 - val_accuracy: 0.9474
# Epoch 76/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1279 - accuracy: 0.9621
# Epoch 76: val_loss improved from 0.12536 to 0.11974, saving model to ./model_weights/finalyearproject_antispoofing_model_76-0.950526.h5
# 168/168 [==============================] - 106s 629ms/step - loss: 0.1279 - accuracy: 0.9621 - val_loss: 0.1197 - val_accuracy: 0.9505
# Epoch 77/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1270 - accuracy: 0.9578
# Epoch 77: val_loss improved from 0.11974 to 0.11682, saving model to ./model_weights/finalyearproject_antispoofing_model_77-0.952632.h5
# 168/168 [==============================] - 108s 644ms/step - loss: 0.1270 - accuracy: 0.9578 - val_loss: 0.1168 - val_accuracy: 0.9526
# Epoch 78/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1356 - accuracy: 0.9538
# Epoch 78: val_loss did not improve from 0.11682
# 168/168 [==============================] - 108s 644ms/step - loss: 0.1356 - accuracy: 0.9538 - val_loss: 0.1191 - val_accuracy: 0.9516
# Epoch 79/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1274 - accuracy: 0.9588
# Epoch 79: val_loss improved from 0.11682 to 0.11108, saving model to ./model_weights/finalyearproject_antispoofing_model_79-0.954737.h5
# 168/168 [==============================] - 107s 638ms/step - loss: 0.1274 - accuracy: 0.9588 - val_loss: 0.1111 - val_accuracy: 0.9547
# Epoch 80/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1282 - accuracy: 0.9569
# Epoch 80: val_loss did not improve from 0.11108
# 168/168 [==============================] - 109s 650ms/step - loss: 0.1282 - accuracy: 0.9569 - val_loss: 0.1176 - val_accuracy: 0.9526
# Epoch 81/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1294 - accuracy: 0.9540
# Epoch 81: val_loss did not improve from 0.11108
# 168/168 [==============================] - 116s 690ms/step - loss: 0.1294 - accuracy: 0.9540 - val_loss: 0.1153 - val_accuracy: 0.9526
# Epoch 82/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1270 - accuracy: 0.9628
# Epoch 82: val_loss did not improve from 0.11108
# 168/168 [==============================] - 116s 693ms/step - loss: 0.1270 - accuracy: 0.9628 - val_loss: 0.1125 - val_accuracy: 0.9526
# Epoch 83/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1190 - accuracy: 0.9616
# Epoch 83: val_loss did not improve from 0.11108
# 168/168 [==============================] - 124s 739ms/step - loss: 0.1190 - accuracy: 0.9616 - val_loss: 0.1112 - val_accuracy: 0.9537
# Epoch 84/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1115 - accuracy: 0.9659
# Epoch 84: val_loss did not improve from 0.11108
# 168/168 [==============================] - 119s 706ms/step - loss: 0.1115 - accuracy: 0.9659 - val_loss: 0.1130 - val_accuracy: 0.9537
# Epoch 85/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1212 - accuracy: 0.9597
# Epoch 85: val_loss improved from 0.11108 to 0.10089, saving model to ./model_weights/finalyearproject_antispoofing_model_85-0.958947.h5
# 168/168 [==============================] - 113s 671ms/step - loss: 0.1212 - accuracy: 0.9597 - val_loss: 0.1009 - val_accuracy: 0.9589
# Epoch 86/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1216 - accuracy: 0.9645
# Epoch 86: val_loss did not improve from 0.10089
# 168/168 [==============================] - 109s 648ms/step - loss: 0.1216 - accuracy: 0.9645 - val_loss: 0.1038 - val_accuracy: 0.9568
# Epoch 87/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1157 - accuracy: 0.9628
# Epoch 87: val_loss did not improve from 0.10089
# 168/168 [==============================] - 112s 664ms/step - loss: 0.1157 - accuracy: 0.9628 - val_loss: 0.1066 - val_accuracy: 0.9547
# Epoch 88/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1185 - accuracy: 0.9623
# Epoch 88: val_loss did not improve from 0.10089
# 168/168 [==============================] - 116s 692ms/step - loss: 0.1185 - accuracy: 0.9623 - val_loss: 0.1044 - val_accuracy: 0.9558
# Epoch 89/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1179 - accuracy: 0.9631
# Epoch 89: val_loss did not improve from 0.10089
# 168/168 [==============================] - 108s 640ms/step - loss: 0.1179 - accuracy: 0.9631 - val_loss: 0.1039 - val_accuracy: 0.9558
# Epoch 90/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1142 - accuracy: 0.9666
# Epoch 90: val_loss did not improve from 0.10089
# 168/168 [==============================] - 111s 657ms/step - loss: 0.1142 - accuracy: 0.9666 - val_loss: 0.1013 - val_accuracy: 0.9558
# Epoch 91/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1178 - accuracy: 0.9628
# Epoch 91: val_loss did not improve from 0.10089
# 168/168 [==============================] - 113s 672ms/step - loss: 0.1178 - accuracy: 0.9628 - val_loss: 0.1022 - val_accuracy: 0.9558
# Epoch 92/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1176 - accuracy: 0.9652
# Epoch 92: val_loss did not improve from 0.10089
# 168/168 [==============================] - 116s 690ms/step - loss: 0.1176 - accuracy: 0.9652 - val_loss: 0.1013 - val_accuracy: 0.9568
# Epoch 93/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1159 - accuracy: 0.9628
# Epoch 93: val_loss improved from 0.10089 to 0.09478, saving model to ./model_weights/finalyearproject_antispoofing_model_93-0.961053.h5
# 168/168 [==============================] - 115s 685ms/step - loss: 0.1159 - accuracy: 0.9628 - val_loss: 0.0948 - val_accuracy: 0.9611
# Epoch 94/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1122 - accuracy: 0.9650
# Epoch 94: val_loss did not improve from 0.09478
# 168/168 [==============================] - 115s 681ms/step - loss: 0.1122 - accuracy: 0.9650 - val_loss: 0.0992 - val_accuracy: 0.9579
# Epoch 95/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1097 - accuracy: 0.9638
# Epoch 95: val_loss did not improve from 0.09478
# 168/168 [==============================] - 120s 712ms/step - loss: 0.1097 - accuracy: 0.9638 - val_loss: 0.0958 - val_accuracy: 0.9611
# Epoch 96/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1134 - accuracy: 0.9619
# Epoch 96: val_loss did not improve from 0.09478
# 168/168 [==============================] - 114s 673ms/step - loss: 0.1134 - accuracy: 0.9619 - val_loss: 0.0975 - val_accuracy: 0.9589
# Epoch 97/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1118 - accuracy: 0.9633
# Epoch 97: val_loss did not improve from 0.09478
# 168/168 [==============================] - 116s 691ms/step - loss: 0.1118 - accuracy: 0.9633 - val_loss: 0.0996 - val_accuracy: 0.9579
# Epoch 98/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1138 - accuracy: 0.9628
# Epoch 98: val_loss improved from 0.09478 to 0.09392, saving model to ./model_weights/finalyearproject_antispoofing_model_98-0.963158.h5
# 168/168 [==============================] - 117s 694ms/step - loss: 0.1138 - accuracy: 0.9628 - val_loss: 0.0939 - val_accuracy: 0.9632
# Epoch 99/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1077 - accuracy: 0.9659
# Epoch 99: val_loss improved from 0.09392 to 0.08794, saving model to ./model_weights/finalyearproject_antispoofing_model_99-0.966316.h5
# 168/168 [==============================] - 119s 708ms/step - loss: 0.1077 - accuracy: 0.9659 - val_loss: 0.0879 - val_accuracy: 0.9663
# Epoch 100/100
# 168/168 [==============================] - ETA: 0s - loss: 0.1112 - accuracy: 0.9650
# Epoch 100: val_loss did not improve from 0.08794
# 168/168 [==============================] - 116s 689ms/step - loss: 0.1112 - accuracy: 0.9650 - val_loss: 0.0944 - val_accuracy: 0.9611

# %%
# serialize model to JSON
model_json = model.to_json()
with open("finalyearproject_antispoofing_model_mobilenet.json", "w") as json_file:
    json_file.write(model_json)

# %%
import matplotlib.pyplot as plt
train_accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']
epochs = range(1,101)
plt.plot(epochs,train_accuracy,'g',label='Training Accuracy')
plt.plot(epochs,validation_accuracy,'b',label='Validation Accuracy')
plt.title('Training Vs Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
train_loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1,101)
plt.plot(epochs,train_loss,'g', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from keras.preprocessing import image
import numpy as np
def check_fakes(path,category_type):
  predictor = {}
  path= os.path.join(path,category_type)
  for img in os.listdir(path):
    try:
      img = image.load_img(os.path.join(path,img),target_size=(160,160))
      img = image.img_to_array(img)
      img = np.expand_dims(img,axis=0)
      img = img / 255.0
      prediction = model.predict(img)
      if prediction > 0.5:
        prediction_class = 1
      else:
        prediction_class = 0
      result = categories[prediction_class]
      if result not in predictor:
        predictor[result] = 1
      else:
        predictor[result] += 1
    except Exception as e:
      pass
  return predictor

# %%
check_fakes(test_dir,categories[1])
# Out:
# {}

# %%
check_fakes(test_dir,categories[0])
# Out:
# {}

# %%
(19+6)/(19+455+471+6)*100
# Out:
# 2.6288117770767614

# %%
100-2.6288
# Out:
# 97.3712
